# %%
import matplotlib.pyplot as plt
import numpy as np
import glob
import cv2
from skimage.util.shape import view_as_windows
# %matplotlib inline

# %%
image = cv2.imread('chimpanzee.png')

# %%
plt.imshow(image)

# %%
b = view_as_windows(image, (88, 88, 3), 88)

# %%
c = b.reshape(-1, 88, 88, 3)

# %%
plt.imshow(c[1, :, :, :])
